# %%
#import libraries
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

# %%
#load a dataset
iris=datasets.load_iris()
x=iris.data[:,:2]  #take the first two features
y=iris.target

# %%
#split the data into training and testing sets
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
#create an SVM classifier
from math import gamma
svm_classifier = SVC(kernel='linear',C=1.0,gamma=0.5)

# %%
# train the SVM classifier, classifier on the training data
svm_classifier.fit(x_train,y_train)
# Out:
# SVC(gamma=0.5, kernel='linear')

# %%
#make predictions on test data
y_pred=svm_classifier.predict(x_test)

# %%
#calculate accuracy
accuracy=accuracy_score(y_test,y_pred)
print(accuracy)
print(f"\nAccuracy:{accuracy*100:.2f}%")
# Out:
# 0.8
#
# Accuracy:80.00%

# %%
#implent svm using rbf kernel
         #Ans:   svm.SVC(kernel="rbf",gamma=0.7,C=1.0)

# %%
#implement svm using polynomial kernel
   #Ans:  svm.SVC(kernel="poly",degree=3,gamma=0.7,C=1.0)

# %%
svm_classifier1 = SVC(kernel='rbf',C=1.0,gamma=0.7)
svm_classifier1.fit(x_train,y_train)
y_pred=svm_classifier1.predict(x_test)
accuracy=accuracy_score(y_test,y_pred)
print(accuracy)
print(f"\nAccuracy:{accuracy*100:.2f}%")
# Out:
# 0.8
#
# Accuracy:80.00%

# %%
svm_classifier2 = SVC(kernel='rbf',C=1.0,gamma=100)
svm_classifier2.fit(x_train,y_train)
y_pred=svm_classifier2.predict(x_test)
accuracy=accuracy_score(y_test,y_pred)
print(accuracy)
print(f"\nAccuracy:{accuracy*100:.2f}%")
# Out:
# 0.5777777777777777
#
# Accuracy:57.78%

# %%
svm_classifier3 = SVC(kernel='rbf',C=1.0,gamma=500)
svm_classifier3.fit(x_train,y_train)
y_pred=svm_classifier3.predict(x_test)
accuracy=accuracy_score(y_test,y_pred)
print(accuracy)
print(f"\nAccuracy:{accuracy*100:.2f}%")
# Out:
# 0.4444444444444444
#
# Accuracy:44.44%
